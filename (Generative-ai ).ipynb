# %%
import requests

# %%
# 1
# !pip install requests -q
# !pip install pyautogen -q

# %%
import requests


API_KEY = "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"

r = requests.post(
    "https://openrouter.ai/api/v1/chat/completions",
    headers={"Authorization": f"Bearer {API_KEY}"},
    json={
        "model": "openai/gpt-3.5-turbo",
        "messages": [{"role": "user", "content": "what is Karbla at iraq"}]
    }
)

print(r.json()['choices'][0]['message']['content'])
# Out:
# The city of Karbala in Iraq is a sacred city for Shia Muslims, as it is the site of the Battle of Karbala in 680 AD where Imam Hussain, the grandson of the Prophet Muhammad, was martyred. This event is commemorated annually during the Islamic month of Muharram, particularly on the day of Ashura, with mourning processions and reenactments of the battle. Karbala also houses the holy shrines of Imam Hussain and his brother Abbas, which are important pilgrimage sites for Shia Muslims.

# %%
# !git clone https://github.com/sajida983/My-first-project.git
# %cd My-first-project
# Out:
# Cloning into 'My-first-project'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# /content/My-first-project

# %%
# !git config --global user.email "sajida983@gmail.com" && git config --global user.name "sajida983" && git clone https://github.com/sajida983/My-first-project.git && cd My-first-project && cp /content/*.ipynb . && git add . && git commit -m "Pushed" && git push origin main
# Out:
# Cloning into 'My-first-project'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.
# cp: cannot stat '/content/*.ipynb': No such file or directory
